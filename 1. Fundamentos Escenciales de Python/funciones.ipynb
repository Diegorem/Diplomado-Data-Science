# %% [markdown]
# # Funciones

# %% [markdown]
# Funciones que no regresan un valor

# %%
def saludar():
    print("Hola")

saludar()
# Out:
# Hola

# %% [markdown]
# Funciones que regresan un valor

# %%
def sumar(a,b):
    return a+b

x = sumar(3,5)
y = sumar(10,20)
z = sumar(x,y)

print("Suma total:", z)
# Out:
# Suma total: 38
