# %% [markdown]
# 10. Reproduce la consulta anterior en Pandas usando pandaSQL

# %%
import pandas as pd
from pandasql import sqldf

# %%
df = pd.read_csv('heroes_information.csv')

query = """
    SELECT Publisher, AVG(Height) FROM df
	    GROUP BY Publisher;
        """

resultado = sqldf(query)

print(resultado)
# Out:
#             Publisher  AVG(Height)
# 0                None    -2.366667
# 1         ABC Studios   -99.000000
# 2           DC Comics    91.072093
# 3   Dark Horse Comics    69.611111
# 4        George Lucas   143.500000
# 5       Hanna-Barbera   -99.000000
# 6       HarperCollins   -99.000000
# 7      IDW Publishing   -99.000000
# 8         Icon Comics   -99.000000
# 9        Image Comics   -76.857143
# 10      J. K. Rowling   -99.000000
# 11   J. R. R. Tolkien   279.000000
# 12      Marvel Comics   142.756443
# 13          Microsoft   213.000000
# 14       NBC - Heroes   -99.000000
# 15          Rebellion   188.000000
# 16           Shueisha   171.500000
# 17      Sony Pictures   179.000000
# 18         South Park   -99.000000
# 19          Star Trek    -5.500000
# 20               SyFy   -99.000000
# 21       Team Epic TV   182.200000
# 22        Titan Books   183.000000
# 23  Universal Studios   -99.000000
# 24          Wildstorm   -99.000000
